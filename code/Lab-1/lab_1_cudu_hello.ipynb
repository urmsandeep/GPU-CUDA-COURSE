# %% [markdown]
# **Lab-1: count_theads.cu and hello.cu**
#
# 03-11-25, v1.0, (c) Incubera AI Labs
#
# **This an introduction to GPU parallelism. ***
#
# Here's what your learn:
#
# *   Count number of threads
# *   We write **once** run many copies
# *   Code Runs in Multiple Places at Once
# *   We can concurrenlty launch multiple ("n") copies of a function (e.g. n=1000)
# *   GPU executes all copies in **parallel**
# *   Each thread gets a **unique ID** (0-(n-1)) automatically
# *   Functions **at the same time**, not one after another

# %%
# !nvidia-smi
# Out:
# Sat Nov  1 22:19:15 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0

# %%
# %%writefile count_threads.cu
# #include <stdio.h>
#
# //  Cardinality (Number of Threads)
# __global__ void countThreads() {
#     // Thread's position within its block
#     int thread_in_block = threadIdx.x;
#
#     // Which block am I in?
#     int my_block = blockIdx.x;
#
#     // My unique global thread ID
#     int global_id = blockIdx.x * blockDim.x + threadIdx.x;
#
#     // Total threads in the grid
#     int total_threads = gridDim.x * blockDim.x;
#
#     printf("Block %d, Thread %d → Global ID: %d (Total: %d threads)\n",
#            my_block, thread_in_block, global_id, total_threads);
# }
#
# int main() {
#     printf("Launching with <<<2, 5>>> (2 blocks, 5 threads each)\n\n");
#     countThreads<<<2, 5>>>();
#     cudaDeviceSynchronize();
#     return 0;
# }
# Out:
# Writing count_threads.cu

# %%
# !nvcc -arch=sm_75 count_threads.cu -o count_threads

# %%
# !./count_threads
# Out:
# Launching with <<<2, 5>>> (2 blocks, 5 threads each)
#
# Block 0, Thread 0 → Global ID: 0 (Total: 10 threads)
# Block 0, Thread 1 → Global ID: 1 (Total: 10 threads)
# Block 0, Thread 2 → Global ID: 2 (Total: 10 threads)
# Block 0, Thread 3 → Global ID: 3 (Total: 10 threads)
# Block 0, Thread 4 → Global ID: 4 (Total: 10 threads)
# Block 1, Thread 0 → Global ID: 5 (Total: 10 threads)
# Block 1, Thread 1 → Global ID: 6 (Total: 10 threads)
# Block 1, Thread 2 → Global ID: 7 (Total: 10 threads)
# Block 1, Thread 3 → Global ID: 8 (Total: 10 threads)
# Block 1, Thread 4 → Global ID: 9 (Total: 10 threads)

# %%
# %%writefile hello.cu
# #include <stdio.h>
#
# //
# __global__ void helloKernel() {
#     printf("Hello from thread %d!\n", threadIdx.x);
# }
#
# int main() {
#     // Check if CUDA device is available
#     int deviceCount;
#     cudaGetDeviceCount(&deviceCount);
#     printf("Found %d CUDA devices\n", deviceCount);
#
#     if (deviceCount == 0) {
#         printf("No CUDA devices found!\n");
#         return 1;
#     }
#
#     // Set larger printf buffer BEFORE launching kernel
#     cudaDeviceSetLimit(cudaLimitPrintfFifoSize, 1024*1024*10);
#
#     printf("Launching kernel from CPU...\n");
#
#     // 1 block, 100 threads
#     helloKernel<<<1, 1000>>>();
#
#     // Check for launch errors
#     cudaError_t launchErr = cudaGetLastError();
#     if (launchErr != cudaSuccess) {
#         printf("Kernel launch error: %s\n", cudaGetErrorString(launchErr));
#         return 1;
#     }
#
#     // Wait and check for execution errors
#     cudaError_t syncErr = cudaDeviceSynchronize();
#     if (syncErr != cudaSuccess) {
#         printf("Kernel execution error: %s\n", cudaGetErrorString(syncErr));
#         return 1;
#     }
#
#     // Force flush - this is key!
#     cudaDeviceReset();
#
#     printf("GPU finished!\n");
#     return 0;
# }
# Out:
# Overwriting hello.cu

# %%
# !nvcc -arch=sm_75 hello.cu -o hello

# %%
# !./hello
# Out:
# Found 1 CUDA devices
# Launching kernel from CPU...
# Hello from thread 992!
# Hello from thread 993!
# Hello from thread 994!
# Hello from thread 995!
# Hello from thread 996!
# Hello from thread 997!
# Hello from thread 998!
# Hello from thread 999!
# Hello from thread 864!
# Hello from thread 865!
# Hello from thread 866!
# Hello from thread 867!
# Hello from thread 868!
# Hello from thread 869!
# Hello from thread 870!
# Hello from thread 871!
# Hello from thread 872!
# Hello from thread 873!
# Hello from thread 874!
# Hello from thread 875!
# Hello from thread 876!
# Hello from thread 877!
# Hello from thread 878!
# Hello from thread 879!
# Hello from thread 880!
# Hello from thread 881!
# Hello from thread 882!
# Hello from thread 883!
# Hello from thread 884!
# Hello from thread 885!
# Hello from thread 886!
# Hello from thread 887!
# Hello from thread 888!
# Hello from thread 889!
# Hello from thread 890!
# Hello from thread 891!
# Hello from thread 892!
# Hello from thread 893!
# Hello from thread 894!
# Hello from thread 895!
# Hello from thread 800!
# Hello from thread 801!
# Hello from thread 802!
# Hello from thread 803!
# Hello from thread 804!
# Hello from thread 805!
# Hello from thread 806!
# Hello from thread 807!
# Hello from thread 808!
# Hello from thread 809!
# Hello from thread 810!
# Hello from thread 811!
# Hello from thread 812!
# Hello from thread 813!
# Hello from thread 814!
# Hello from thread 815!
# Hello from thread 816!
# Hello from thread 817!
# Hello from thread 818!
# Hello from thread 819!
# Hello from thread 820!
# Hello from thread 821!
# Hello from thread 822!
# Hello from thread 823!
# Hello from thread 824!
# Hello from thread 825!
# Hello from thread 826!
# Hello from thread 827!
# Hello from thread 828!
# Hello from thread 829!
# Hello from thread 830!
# Hello from thread 831!
# Hello from thread 768!
# Hello from thread 769!
# Hello from thread 770!
# Hello from thread 771!
# Hello from thread 772!
# Hello from thread 773!
# Hello from thread 774!
# Hello from thread 775!
# Hello from thread 776!
# Hello from thread 777!
# Hello from thread 778!
# Hello from thread 779!
# Hello from thread 780!
# Hello from thread 781!
# Hello from thread 782!
# Hello from thread 783!
# Hello from thread 784!
# Hello from thread 785!
# Hello from thread 786!
# Hello from thread 787!
# Hello from thread 788!
# Hello from thread 789!
# Hello from thread 790!
# Hello from thread 791!
# Hello from thread 792!
# Hello from thread 793!
# Hello from thread 794!
# Hello from thread 795!
# Hello from thread 796!
# Hello from thread 797!
# Hello from thread 798!
# Hello from thread 799!
# Hello from thread 512!
# Hello from thread 513!
# Hello from thread 514!
# Hello from thread 515!
# Hello from thread 516!
# Hello from thread 517!
# Hello from thread 518!
# Hello from thread 519!
# Hello from thread 520!
# Hello from thread 521!
# Hello from thread 522!
# Hello from thread 523!
# Hello from thread 524!
# Hello from thread 525!
# Hello from thread 526!
# Hello from thread 527!
# Hello from thread 528!
# Hello from thread 529!
# Hello from thread 530!
# Hello from thread 531!
# Hello from thread 532!
# Hello from thread 533!
# Hello from thread 534!
# Hello from thread 535!
# Hello from thread 536!
# Hello from thread 537!
# Hello from thread 538!
# Hello from thread 539!
# Hello from thread 540!
# Hello from thread 541!
# Hello from thread 542!
# Hello from thread 543!
# Hello from thread 640!
# Hello from thread 641!
# Hello from thread 642!
# Hello from thread 643!
# Hello from thread 644!
# Hello from thread 645!
# Hello from thread 646!
# Hello from thread 647!
# Hello from thread 648!
# Hello from thread 649!
# Hello from thread 650!
# Hello from thread 651!
# Hello from thread 652!
# Hello from thread 653!
# Hello from thread 654!
# Hello from thread 655!
# Hello from thread 656!
# Hello from thread 657!
# Hello from thread 658!
# Hello from thread 659!
# Hello from thread 660!
# Hello from thread 661!
# Hello from thread 662!
# Hello from thread 663!
# Hello from thread 664!
# Hello from thread 665!
# Hello from thread 666!
# Hello from thread 667!
# Hello from thread 668!
# Hello from thread 669!
# Hello from thread 670!
# Hello from thread 671!
# Hello from thread 352!
# Hello from thread 353!
# Hello from thread 354!
# Hello from thread 355!
# Hello from thread 356!
# Hello from thread 357!
# Hello from thread 358!
# Hello from thread 359!
# Hello from thread 360!
# Hello from thread 361!
# Hello from thread 362!
# Hello from thread 363!
# Hello from thread 364!
# Hello from thread 365!
# Hello from thread 366!
# Hello from thread 367!
# Hello from thread 368!
# Hello from thread 369!
# Hello from thread 370!
# Hello from thread 371!
# Hello from thread 372!
# Hello from thread 373!
# Hello from thread 374!
# Hello from thread 375!
# Hello from thread 376!
# Hello from thread 377!
# Hello from thread 378!
# Hello from thread 379!
# Hello from thread 380!
# Hello from thread 381!
# Hello from thread 382!
# Hello from thread 383!
# Hello from thread 736!
# Hello from thread 737!
# Hello from thread 738!
# Hello from thread 739!
# Hello from thread 740!
# Hello from thread 741!
# Hello from thread 742!
# Hello from thread 743!
# Hello from thread 744!
# Hello from thread 745!
# Hello from thread 746!
# Hello from thread 747!
# Hello from thread 748!
# Hello from thread 749!
# Hello from thread 750!
# Hello from thread 751!
# Hello from thread 752!
# Hello from thread 753!
# Hello from thread 754!
# Hello from thread 755!
# Hello from thread 756!
# Hello from thread 757!
# Hello from thread 758!
# Hello from thread 759!
# Hello from thread 760!
# Hello from thread 761!
# Hello from thread 762!
# Hello from thread 763!
# Hello from thread 764!
# Hello from thread 765!
# Hello from thread 766!
# Hello from thread 767!
# Hello from thread 928!
# Hello from thread 929!
# Hello from thread 930!
# Hello from thread 931!
# Hello from thread 932!
# Hello from thread 933!
# Hello from thread 934!
# Hello from thread 935!
# Hello from thread 936!
# Hello from thread 937!
# Hello from thread 938!
# Hello from thread 939!
# Hello from thread 940!
# Hello from thread 941!
# Hello from thread 942!
# Hello from thread 943!
# Hello from thread 944!
# Hello from thread 945!
# Hello from thread 946!
# Hello from thread 947!
# Hello from thread 948!
# Hello from thread 949!
# Hello from thread 950!
# Hello from thread 951!
# Hello from thread 952!
# Hello from thread 953!
# Hello from thread 954!
# Hello from thread 955!
# Hello from thread 956!
# Hello from thread 957!
# Hello from thread 958!
# Hello from thread 959!
# Hello from thread 416!
# Hello from thread 417!
# Hello from thread 418!
# Hello from thread 419!
# Hello from thread 420!
# Hello from thread 421!
# Hello from thread 422!
# Hello from thread 423!
# Hello from thread 424!
# Hello from thread 425!
# Hello from thread 426!
# Hello from thread 427!
# Hello from thread 428!
# Hello from thread 429!
# Hello from thread 430!
# Hello from thread 431!
# Hello from thread 432!
# Hello from thread 433!
# Hello from thread 434!
# Hello from thread 435!
# Hello from thread 436!
# Hello from thread 437!
# Hello from thread 438!
# Hello from thread 439!
# Hello from thread 440!
# Hello from thread 441!
# Hello from thread 442!
# Hello from thread 443!
# Hello from thread 444!
# Hello from thread 445!
# Hello from thread 446!
# Hello from thread 447!
# Hello from thread 896!
# Hello from thread 897!
# Hello from thread 898!
# Hello from thread 899!
# Hello from thread 900!
# Hello from thread 901!
# Hello from thread 902!
# Hello from thread 903!
# Hello from thread 904!
# Hello from thread 905!
# Hello from thread 906!
# Hello from thread 907!
# Hello from thread 908!
# Hello from thread 909!
# Hello from thread 910!
# Hello from thread 911!
# Hello from thread 912!
# Hello from thread 913!
# Hello from thread 914!
# Hello from thread 915!
# Hello from thread 916!
# Hello from thread 917!
# Hello from thread 918!
# Hello from thread 919!
# Hello from thread 920!
# Hello from thread 921!
# Hello from thread 922!
# Hello from thread 923!
# Hello from thread 924!
# Hello from thread 925!
# Hello from thread 926!
# Hello from thread 927!
# Hello from thread 960!
# Hello from thread 961!
# Hello from thread 962!
# Hello from thread 963!
# Hello from thread 964!
# Hello from thread 965!
# Hello from thread 966!
# Hello from thread 967!
# Hello from thread 968!
# Hello from thread 969!
# Hello from thread 970!
# Hello from thread 971!
# Hello from thread 972!
# Hello from thread 973!
# Hello from thread 974!
# Hello from thread 975!
# Hello from thread 976!
# Hello from thread 977!
# Hello from thread 978!
# Hello from thread 979!
# Hello from thread 980!
# Hello from thread 981!
# Hello from thread 982!
# Hello from thread 983!
# Hello from thread 984!
# Hello from thread 985!
# Hello from thread 986!
# Hello from thread 987!
# Hello from thread 988!
# Hello from thread 989!
# Hello from thread 990!
# Hello from thread 991!
# Hello from thread 544!
# Hello from thread 545!
# Hello from thread 546!
# Hello from thread 547!
# Hello from thread 548!
# Hello from thread 549!
# Hello from thread 550!
# Hello from thread 551!
# Hello from thread 552!
# Hello from thread 553!
# Hello from thread 554!
# Hello from thread 555!
# Hello from thread 556!
# Hello from thread 557!
# Hello from thread 558!
# Hello from thread 559!
# Hello from thread 560!
# Hello from thread 561!
# Hello from thread 562!
# Hello from thread 563!
# Hello from thread 564!
# Hello from thread 565!
# Hello from thread 566!
# Hello from thread 567!
# Hello from thread 568!
# Hello from thread 569!
# Hello from thread 570!
# Hello from thread 571!
# Hello from thread 572!
# Hello from thread 573!
# Hello from thread 574!
# Hello from thread 575!
# Hello from thread 480!
# Hello from thread 481!
# Hello from thread 482!
# Hello from thread 483!
# Hello from thread 484!
# Hello from thread 485!
# Hello from thread 486!
# Hello from thread 487!
# Hello from thread 488!
# Hello from thread 489!
# Hello from thread 490!
# Hello from thread 491!
# Hello from thread 492!
# Hello from thread 493!
# Hello from thread 494!
# Hello from thread 495!
# Hello from thread 496!
# Hello from thread 497!
# Hello from thread 498!
# Hello from thread 499!
# Hello from thread 500!
# Hello from thread 501!
# Hello from thread 502!
# Hello from thread 503!
# Hello from thread 504!
# Hello from thread 505!
# Hello from thread 506!
# Hello from thread 507!
# Hello from thread 508!
# Hello from thread 509!
# Hello from thread 510!
# Hello from thread 511!
# Hello from thread 128!
# Hello from thread 129!
# Hello from thread 130!
# Hello from thread 131!
# Hello from thread 132!
# Hello from thread 133!
# Hello from thread 134!
# Hello from thread 135!
# Hello from thread 136!
# Hello from thread 137!
# Hello from thread 138!
# Hello from thread 139!
# Hello from thread 140!
# Hello from thread 141!
# Hello from thread 142!
# Hello from thread 143!
# Hello from thread 144!
# Hello from thread 145!
# Hello from thread 146!
# Hello from thread 147!
# Hello from thread 148!
# Hello from thread 149!
# Hello from thread 150!
# Hello from thread 151!
# Hello from thread 152!
# Hello from thread 153!
# Hello from thread 154!
# Hello from thread 155!
# Hello from thread 156!
# Hello from thread 157!
# Hello from thread 158!
# Hello from thread 159!
# Hello from thread 96!
# Hello from thread 97!
# Hello from thread 98!
# Hello from thread 99!
# Hello from thread 100!
# Hello from thread 101!
# Hello from thread 102!
# Hello from thread 103!
# Hello from thread 104!
# Hello from thread 105!
# Hello from thread 106!
# Hello from thread 107!
# Hello from thread 108!
# Hello from thread 109!
# Hello from thread 110!
# Hello from thread 111!
# Hello from thread 112!
# Hello from thread 113!
# Hello from thread 114!
# Hello from thread 115!
# Hello from thread 116!
# Hello from thread 117!
# Hello from thread 118!
# Hello from thread 119!
# Hello from thread 120!
# Hello from thread 121!
# Hello from thread 122!
# Hello from thread 123!
# Hello from thread 124!
# Hello from thread 125!
# Hello from thread 126!
# Hello from thread 127!
# Hello from thread 224!
# Hello from thread 225!
# Hello from thread 226!
# Hello from thread 227!
# Hello from thread 228!
# Hello from thread 229!
# Hello from thread 230!
# Hello from thread 231!
# Hello from thread 232!
# Hello from thread 233!
# Hello from thread 234!
# Hello from thread 235!
# Hello from thread 236!
# Hello from thread 237!
# Hello from thread 238!
# Hello from thread 239!
# Hello from thread 240!
# Hello from thread 241!
# Hello from thread 242!
# Hello from thread 243!
# Hello from thread 244!
# Hello from thread 245!
# Hello from thread 246!
# Hello from thread 247!
# Hello from thread 248!
# Hello from thread 249!
# Hello from thread 250!
# Hello from thread 251!
# Hello from thread 252!
# Hello from thread 253!
# Hello from thread 254!
# Hello from thread 255!
# Hello from thread 288!
# Hello from thread 289!
# Hello from thread 290!
# Hello from thread 291!
# Hello from thread 292!
# Hello from thread 293!
# Hello from thread 294!
# Hello from thread 295!
# Hello from thread 296!
# Hello from thread 297!
# Hello from thread 298!
# Hello from thread 299!
# Hello from thread 300!
# Hello from thread 301!
# Hello from thread 302!
# Hello from thread 303!
# Hello from thread 304!
# Hello from thread 305!
# Hello from thread 306!
# Hello from thread 307!
# Hello from thread 308!
# Hello from thread 309!
# Hello from thread 310!
# Hello from thread 311!
# Hello from thread 312!
# Hello from thread 313!
# Hello from thread 314!
# Hello from thread 315!
# Hello from thread 316!
# Hello from thread 317!
# Hello from thread 318!
# Hello from thread 319!
# Hello from thread 32!
# Hello from thread 33!
# Hello from thread 34!
# Hello from thread 35!
# Hello from thread 36!
# Hello from thread 37!
# Hello from thread 38!
# Hello from thread 39!
# Hello from thread 40!
# Hello from thread 41!
# Hello from thread 42!
# Hello from thread 43!
# Hello from thread 44!
# Hello from thread 45!
# Hello from thread 46!
# Hello from thread 47!
# Hello from thread 48!
# Hello from thread 49!
# Hello from thread 50!
# Hello from thread 51!
# Hello from thread 52!
# Hello from thread 53!
# Hello from thread 54!
# Hello from thread 55!
# Hello from thread 56!
# Hello from thread 57!
# Hello from thread 58!
# Hello from thread 59!
# Hello from thread 60!
# Hello from thread 61!
# Hello from thread 62!
# Hello from thread 63!
# Hello from thread 832!
# Hello from thread 833!
# Hello from thread 834!
# Hello from thread 835!
# Hello from thread 836!
# Hello from thread 837!
# Hello from thread 838!
# Hello from thread 839!
# Hello from thread 840!
# Hello from thread 841!
# Hello from thread 842!
# Hello from thread 843!
# Hello from thread 844!
# Hello from thread 845!
# Hello from thread 846!
# Hello from thread 847!
# Hello from thread 848!
# Hello from thread 849!
# Hello from thread 850!
# Hello from thread 851!
# Hello from thread 852!
# Hello from thread 853!
# Hello from thread 854!
# Hello from thread 855!
# Hello from thread 856!
# Hello from thread 857!
# Hello from thread 858!
# Hello from thread 859!
# Hello from thread 860!
# Hello from thread 861!
# Hello from thread 862!
# Hello from thread 863!
# Hello from thread 64!
# Hello from thread 65!
# Hello from thread 66!
# Hello from thread 67!
# Hello from thread 68!
# Hello from thread 69!
# Hello from thread 70!
# Hello from thread 71!
# Hello from thread 72!
# Hello from thread 73!
# Hello from thread 74!
# Hello from thread 75!
# Hello from thread 76!
# Hello from thread 77!
# Hello from thread 78!
# Hello from thread 79!
# Hello from thread 80!
# Hello from thread 81!
# Hello from thread 82!
# Hello from thread 83!
# Hello from thread 84!
# Hello from thread 85!
# Hello from thread 86!
# Hello from thread 87!
# Hello from thread 88!
# Hello from thread 89!
# Hello from thread 90!
# Hello from thread 91!
# Hello from thread 92!
# Hello from thread 93!
# Hello from thread 94!
# Hello from thread 95!
# Hello from thread 576!
# Hello from thread 577!
# Hello from thread 578!
# Hello from thread 579!
# Hello from thread 580!
# Hello from thread 581!
# Hello from thread 582!
# Hello from thread 583!
# Hello from thread 584!
# Hello from thread 585!
# Hello from thread 586!
# Hello from thread 587!
# Hello from thread 588!
# Hello from thread 589!
# Hello from thread 590!
# Hello from thread 591!
# Hello from thread 592!
# Hello from thread 593!
# Hello from thread 594!
# Hello from thread 595!
# Hello from thread 596!
# Hello from thread 597!
# Hello from thread 598!
# Hello from thread 599!
# Hello from thread 600!
# Hello from thread 601!
# Hello from thread 602!
# Hello from thread 603!
# Hello from thread 604!
# Hello from thread 605!
# Hello from thread 606!
# Hello from thread 607!
# Hello from thread 192!
# Hello from thread 193!
# Hello from thread 194!
# Hello from thread 195!
# Hello from thread 196!
# Hello from thread 197!
# Hello from thread 198!
# Hello from thread 199!
# Hello from thread 200!
# Hello from thread 201!
# Hello from thread 202!
# Hello from thread 203!
# Hello from thread 204!
# Hello from thread 205!
# Hello from thread 206!
# Hello from thread 207!
# Hello from thread 208!
# Hello from thread 209!
# Hello from thread 210!
# Hello from thread 211!
# Hello from thread 212!
# Hello from thread 213!
# Hello from thread 214!
# Hello from thread 215!
# Hello from thread 216!
# Hello from thread 217!
# Hello from thread 218!
# Hello from thread 219!
# Hello from thread 220!
# Hello from thread 221!
# Hello from thread 222!
# Hello from thread 223!
# Hello from thread 448!
# Hello from thread 449!
# Hello from thread 450!
# Hello from thread 451!
# Hello from thread 452!
# Hello from thread 453!
# Hello from thread 454!
# Hello from thread 455!
# Hello from thread 456!
# Hello from thread 457!
# Hello from thread 458!
# Hello from thread 459!
# Hello from thread 460!
# Hello from thread 461!
# Hello from thread 462!
# Hello from thread 463!
# Hello from thread 464!
# Hello from thread 465!
# Hello from thread 466!
# Hello from thread 467!
# Hello from thread 468!
# Hello from thread 469!
# Hello from thread 470!
# Hello from thread 471!
# Hello from thread 472!
# Hello from thread 473!
# Hello from thread 474!
# Hello from thread 475!
# Hello from thread 476!
# Hello from thread 477!
# Hello from thread 478!
# Hello from thread 479!
# Hello from thread 384!
# Hello from thread 385!
# Hello from thread 386!
# Hello from thread 387!
# Hello from thread 388!
# Hello from thread 389!
# Hello from thread 390!
# Hello from thread 391!
# Hello from thread 392!
# Hello from thread 393!
# Hello from thread 394!
# Hello from thread 395!
# Hello from thread 396!
# Hello from thread 397!
# Hello from thread 398!
# Hello from thread 399!
# Hello from thread 400!
# Hello from thread 401!
# Hello from thread 402!
# Hello from thread 403!
# Hello from thread 404!
# Hello from thread 405!
# Hello from thread 406!
# Hello from thread 407!
# Hello from thread 408!
# Hello from thread 409!
# Hello from thread 410!
# Hello from thread 411!
# Hello from thread 412!
# Hello from thread 413!
# Hello from thread 414!
# Hello from thread 415!
# Hello from thread 0!
# Hello from thread 1!
# Hello from thread 2!
# Hello from thread 3!
# Hello from thread 4!
# Hello from thread 5!
# Hello from thread 6!
# Hello from thread 7!
# Hello from thread 8!
# Hello from thread 9!
# Hello from thread 10!
# Hello from thread 11!
# Hello from thread 12!
# Hello from thread 13!
# Hello from thread 14!
# Hello from thread 15!
# Hello from thread 16!
# Hello from thread 17!
# Hello from thread 18!
# Hello from thread 19!
# Hello from thread 20!
# Hello from thread 21!
# Hello from thread 22!
# Hello from thread 23!
# Hello from thread 24!
# Hello from thread 25!
# Hello from thread 26!
# Hello from thread 27!
# Hello from thread 28!
# Hello from thread 29!
# Hello from thread 30!
# Hello from thread 31!
# Hello from thread 608!
# Hello from thread 609!
# Hello from thread 610!
# Hello from thread 611!
# Hello from thread 612!
# Hello from thread 613!
# Hello from thread 614!
# Hello from thread 615!
# Hello from thread 616!
# Hello from thread 617!
# Hello from thread 618!
# Hello from thread 619!
# Hello from thread 620!
# Hello from thread 621!
# Hello from thread 622!
# Hello from thread 623!
# Hello from thread 624!
# Hello from thread 625!
# Hello from thread 626!
# Hello from thread 627!
# Hello from thread 628!
# Hello from thread 629!
# Hello from thread 630!
# Hello from thread 631!
# Hello from thread 632!
# Hello from thread 633!
# Hello from thread 634!
# Hello from thread 635!
# Hello from thread 636!
# Hello from thread 637!
# Hello from thread 638!
# Hello from thread 639!
# Hello from thread 704!
# Hello from thread 705!
# Hello from thread 706!
# Hello from thread 707!
# Hello from thread 708!
# Hello from thread 709!
# Hello from thread 710!
# Hello from thread 711!
# Hello from thread 712!
# Hello from thread 713!
# Hello from thread 714!
# Hello from thread 715!
# Hello from thread 716!
# Hello from thread 717!
# Hello from thread 718!
# Hello from thread 719!
# Hello from thread 720!
# Hello from thread 721!
# Hello from thread 722!
# Hello from thread 723!
# Hello from thread 724!
# Hello from thread 725!
# Hello from thread 726!
# Hello from thread 727!
# Hello from thread 728!
# Hello from thread 729!
# Hello from thread 730!
# Hello from thread 731!
# Hello from thread 732!
# Hello from thread 733!
# Hello from thread 734!
# Hello from thread 735!
# Hello from thread 672!
# Hello from thread 673!
# Hello from thread 674!
# Hello from thread 675!
# Hello from thread 676!
# Hello from thread 677!
# Hello from thread 678!
# Hello from thread 679!
# Hello from thread 680!
# Hello from thread 681!
# Hello from thread 682!
# Hello from thread 683!
# Hello from thread 684!
# Hello from thread 685!
# Hello from thread 686!
# Hello from thread 687!
# Hello from thread 688!
# Hello from thread 689!
# Hello from thread 690!
# Hello from thread 691!
# Hello from thread 692!
# Hello from thread 693!
# Hello from thread 694!
# Hello from thread 695!
# Hello from thread 696!
# Hello from thread 697!
# Hello from thread 698!
# Hello from thread 699!
# Hello from thread 700!
# Hello from thread 701!
# Hello from thread 702!
# Hello from thread 703!
# Hello from thread 160!
# Hello from thread 161!
# Hello from thread 162!
# Hello from thread 163!
# Hello from thread 164!
# Hello from thread 165!
# Hello from thread 166!
# Hello from thread 167!
# Hello from thread 168!
# Hello from thread 169!
# Hello from thread 170!
# Hello from thread 171!
# Hello from thread 172!
# Hello from thread 173!
# Hello from thread 174!
# Hello from thread 175!
# Hello from thread 176!
# Hello from thread 177!
# Hello from thread 178!
# Hello from thread 179!
# Hello from thread 180!
# Hello from thread 181!
# Hello from thread 182!
# Hello from thread 183!
# Hello from thread 184!
# Hello from thread 185!
# Hello from thread 186!
# Hello from thread 187!
# Hello from thread 188!
# Hello from thread 189!
# Hello from thread 190!
# Hello from thread 191!
# Hello from thread 256!
# Hello from thread 257!
# Hello from thread 258!
# Hello from thread 259!
# Hello from thread 260!
# Hello from thread 261!
# Hello from thread 262!
# Hello from thread 263!
# Hello from thread 264!
# Hello from thread 265!
# Hello from thread 266!
# Hello from thread 267!
# Hello from thread 268!
# Hello from thread 269!
# Hello from thread 270!
# Hello from thread 271!
# Hello from thread 272!
# Hello from thread 273!
# Hello from thread 274!
# Hello from thread 275!
# Hello from thread 276!
# Hello from thread 277!
# Hello from thread 278!
# Hello from thread 279!
# Hello from thread 280!
# Hello from thread 281!
# Hello from thread 282!
# Hello from thread 283!
# Hello from thread 284!
# Hello from thread 285!
# Hello from thread 286!
# Hello from thread 287!
# Hello from thread 320!
# Hello from thread 321!
# Hello from thread 322!
# Hello from thread 323!
# Hello from thread 324!
# Hello from thread 325!
# Hello from thread 326!
# Hello from thread 327!
# Hello from thread 328!
# Hello from thread 329!
# Hello from thread 330!
# Hello from thread 331!
# Hello from thread 332!
# Hello from thread 333!
# Hello from thread 334!
# Hello from thread 335!
# Hello from thread 336!
# Hello from thread 337!
# Hello from thread 338!
# Hello from thread 339!
# Hello from thread 340!
# Hello from thread 341!
# Hello from thread 342!
# Hello from thread 343!
# Hello from thread 344!
# Hello from thread 345!
# Hello from thread 346!
# Hello from thread 347!
# Hello from thread 348!
# Hello from thread 349!
# Hello from thread 350!
# Hello from thread 351!
# GPU finished!
